# %% [markdown]
# # 13. Wide-Table Coverage Filter (Additive)
#
# This notebook creates a coverage-filtered wide training table as an additive artifact for faster follow-up DP-SGD experiments.
#
# It does not modify existing wide-table artifacts.

# %%
from pathlib import Path
import sys
import pandas as pd
from IPython.display import display, Markdown

ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

from src.experiments.wide_filter import build_coverage_filtered_wide_table, summarize_numeric_sparsity

INPUT_WIDE = ROOT / 'data' / 'reporting' / 'wide_training_table.parquet'
OUT_DIR = ROOT / 'data' / 'experiments_additive' / 'wide_filter'
OUT_DIR.mkdir(parents=True, exist_ok=True)
FILTERED_WIDE = OUT_DIR / 'wide_training_table_cov3.parquet'

display(Markdown(f"Input wide table: `{INPUT_WIDE}`"))
# Out:
# Input wide table: `/Users/enscribe/Repositories/School/dsc180-q2/data/reporting/wide_training_table.parquet`

# %%
summary = build_coverage_filtered_wide_table(
    input_path=INPUT_WIDE,
    output_path=FILTERED_WIDE,
    min_nonzero_numeric=3,
)

display(Markdown('## Coverage filter summary'))
display(pd.DataFrame([{
    'input_rows': summary.input_rows,
    'output_rows': summary.output_rows,
    'retention_rate': summary.output_rows / summary.input_rows if summary.input_rows else 0.0,
    'numeric_cols': summary.numeric_cols,
    'threshold': summary.threshold,
    'output_path': str(summary.output_path),
}]))
# Out:
# ## Coverage filter summary
#    input_rows  output_rows  retention_rate  numeric_cols  threshold  \
# 0     1000000       282315        0.282315            59          3
#
#                                          output_path
# 0  /Users/enscribe/Repositories/School/dsc180-q2/...

# %%
display(Markdown('## Lowest nonzero-rate numeric columns in original wide table'))
display(summarize_numeric_sparsity(INPUT_WIDE, top_k=20))

display(Markdown('## Lowest nonzero-rate numeric columns in filtered wide table'))
display(summarize_numeric_sparsity(FILTERED_WIDE, top_k=20))
# Out:
# ## Lowest nonzero-rate numeric columns in original wide table
#                                                column  nonzero_rows  \
# 49                                       psys_rap_nrs           611
# 50                                       psys_rap_avg           611
# 54                                       avg_freq_avg           613
# 53                                       avg_freq_nrs           613
# 56                                           temp_avg           621
# 55                                           temp_nrs           622
# 58                                      pkg_power_avg           800
# 57                                      pkg_power_nrs           800
# 28                            webcat_productivity_crm           874
# 32             webcat_productivity_project_management          3627
# 15  webcat_content_creation_video_audio_edit_creation          5034
# 30                  webcat_productivity_presentations          7569
# 23                           webcat_games_video_games          8508
# 52                                         pkg_c0_avg          8933
# 51                                         pkg_c0_nrs          8943
# 44                                    onoff_mods_time         10540
# 18         webcat_entertainment_music_audio_streaming         11236
# 11                               web_firefox_duration         11801
# 33                   webcat_productivity_spreadsheets         11947
# 14        webcat_content_creation_photo_edit_creation         13117
#
#     nonzero_rate
# 49      0.000611
# 50      0.000611
# 54      0.000613
# 53      0.000613
# 56      0.000621
# 55      0.000622
# 58      0.000800
# 57      0.000800
# 28      0.000874
# 32      0.003627
# 15      0.005034
# 30      0.007569
# 23      0.008508
# 52      0.008933
# 51      0.008943
# 44      0.010540
# 18      0.011236
# 11      0.011801
# 33      0.011947
# 14      0.013117
# ## Lowest nonzero-rate numeric columns in filtered wide table
#                                                column  nonzero_rows  \
# 49                                       psys_rap_nrs           611
# 50                                       psys_rap_avg           611
# 54                                       avg_freq_avg           613
# 53                                       avg_freq_nrs           613
# 56                                           temp_avg           621
# 55                                           temp_nrs           622
# 58                                      pkg_power_avg           800
# 57                                      pkg_power_nrs           800
# 28                            webcat_productivity_crm           874
# 32             webcat_productivity_project_management          3627
# 15  webcat_content_creation_video_audio_edit_creation          5034
# 30                  webcat_productivity_presentations          7569
# 23                           webcat_games_video_games          8508
# 52                                         pkg_c0_avg          8933
# 51                                         pkg_c0_nrs          8939
# 44                                    onoff_mods_time         10540
# 18         webcat_entertainment_music_audio_streaming         11236
# 11                               web_firefox_duration         11801
# 33                   webcat_productivity_spreadsheets         11947
# 14        webcat_content_creation_photo_edit_creation         13117
#
#     nonzero_rate
# 49      0.002164
# 50      0.002164
# 54      0.002171
# 53      0.002171
# 56      0.002200
# 55      0.002203
# 58      0.002834
# 57      0.002834
# 28      0.003096
# 32      0.012847
# 15      0.017831
# 30      0.026810
# 23      0.030137
# 52      0.031642
# 51      0.031663
# 44      0.037334
# 18      0.039800
# 11      0.041801
# 33      0.042318
# 14      0.046462
